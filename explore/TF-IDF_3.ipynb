# %% [markdown]
# <a href="https://colab.research.google.com/github/opsifiz/AIB5_Emotion-Classification/blob/main/explore/TF_IDF_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
# print(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
df = pd.read_csv('drive/MyDrive/train_dataset2.csv')
df
# Out:
#                                                     text   status
# 0                                             oh my gosh  Anxiety
# 1      trouble sleeping confused mind restless heart ...  Anxiety
# 2      all wrong back off dear forward doubt stay in ...  Anxiety
# 3      i have shifted my focus to something else but ...  Anxiety
# 4      i am restless and restless it is been a month ...  Anxiety
# ...                                                  ...      ...
# 89995  tw strong arm abuse my dad was screaming at me...   Stress
# 89996  hi i cannot think clearly today i know i have ...   Stress
# 89997  my chest give a dissimilar aroma before it wou...   Stress
# 89998  he was going to choke the name out of me i am ...   Stress
# 89999  hurt the ego but whatever i speculation you ar...   Stress
#
# [90000 rows x 2 columns]

# %%
df.describe()
# Out:
#                                                      text   status
# count                                               90000    90000
# unique                                              90000        9
# top     is this a psychological condition or scarce in...  Anxiety
# freq                                                    1    10000

# %%
grouped = df.groupby('status')['text'].apply(lambda texts: ' '.join(texts))

# %%
grouped.head(10)
# Out:
# status
# Anxiety          oh my gosh trouble sleeping confused mind rest...
# BPD              my father all of my life has shifted between a...
# Normal           gr gr dreaming of ex crush to be my game god w...
# Stress           he said he had not felt that way before sugget...
# Suicidal         i am so exhausted of this just when i think i ...
# bipolar          what birth control are you on i tried an iud b...
# depression       i recently went through a breakup and she said...
# mentalillness    i feel the same towards a loved one and a comp...
# schizophrenia    does anyone else get frequent delusions that n...
# Name: text, dtype: object

# %%
stop_words = set(stopwords.words('english'))

# %%
def remove_stopwords(text):
    words = text.split()  # Tokenize and lowercase
    filtered_words = [word for word in words if word.isalpha() and word not in stop_words]
    return ' '.join(filtered_words)

# %%
all_status = grouped.index.to_list()
all_status
# Out:
# ['Anxiety',
#  'BPD',
#  'Normal',
#  'Stress',
#  'Suicidal',
#  'bipolar',
#  'depression',
#  'mentalillness',
#  'schizophrenia']

# %%
for status in all_status:
  grouped[status] = remove_stopwords(grouped[status])

# %%
grouped.head(10)
# Out:
# status
# Anxiety          oh gosh trouble sleeping confused mind restles...
# BPD              father life shifted wonderful person monster b...
# Normal           gr gr dreaming ex crush game god wkwkwk joke l...
# Stress           said felt way suggeted go rest trigger ahead y...
# Suicidal         exhausted think finally rest think maybe thing...
# bipolar          birth control tried iud came traumatic assault...
# depression       recently went breakup said still wants friends...
# mentalillness    feel towards loved one complete stranger feel ...
# schizophrenia    anyone else get frequent delusions nobody like...
# Name: text, dtype: object

# %%
vectorizer = TfidfVectorizer()
tfidf_matrix = vectorizer.fit_transform(grouped)

# %%
tfidf_df = pd.DataFrame(tfidf_matrix.toarray(),
                        index=grouped.index,
                        columns=vectorizer.get_feature_names_out())

# %%
top_n = 10
for status in tfidf_df.index:
    print(f"\nTop words for status '{status}':")
    top_words = tfidf_df.loc[status].sort_values(ascending=False).head(top_n)
    print(top_words)
# Out:
# Top words for status 'Anxiety':
# anxiety    0.349137
# like       0.332297
# feel       0.249566
# get        0.193880
# know       0.191679
# really     0.152961
# time       0.146359
# would      0.138800
# cannot     0.130763
# even       0.129455
# Name: Anxiety, dtype: float64
#
# Top words for status 'BPD':
# like      0.373983
# feel      0.293938
# know      0.235378
# want      0.192753
# would     0.182271
# get       0.167922
# really    0.164304
# bpd       0.157712
# time      0.148543
# people    0.146015
# Name: BPD, dtype: float64
#
# Top words for status 'Normal':
# like      0.281143
# want      0.259156
# would     0.207266
# really    0.201403
# get       0.171500
# time      0.170914
# know      0.165051
# one       0.158308
# people    0.148927
# go        0.146581
# Name: Normal, dtype: float64
#
# Top words for status 'Stress':
# like      0.303385
# feel      0.232285
# get       0.229313
# stress    0.216320
# know      0.185828
# time      0.177774
# would     0.163007
# cannot    0.162528
# even      0.143782
# work      0.143446
# Name: Stress, dtype: float64
#
# Top words for status 'Suicidal':
# want      0.317080
# like      0.272653
# cannot    0.238914
# life      0.228317
# feel      0.225820
# know      0.213244
# would     0.172775
# get       0.156850
# even      0.155662
# people    0.142538
# Name: Suicidal, dtype: float64
#
# Top words for status 'bipolar':
# like       0.342254
# feel       0.263085
# know       0.208642
# bipolar    0.191053
# get        0.180528
# time       0.156695
# really     0.156374
# would      0.149417
# want       0.149167
# cannot     0.125585
# Name: bipolar, dtype: float64
#
# Top words for status 'depression':
# like      0.342712
# feel      0.308039
# want      0.232685
# know      0.217449
# life      0.204633
# cannot    0.183973
# get       0.181261
# even      0.168950
# time      0.146136
# people    0.145524
# Name: depression, dtype: float64
#
# Top words for status 'mentalillness':
# like      0.379161
# feel      0.265459
# know      0.238116
# get       0.190033
# would     0.186609
# want      0.177070
# really    0.154472
# people    0.154178
# cannot    0.149458
# even      0.148847
# Name: mentalillness, dtype: float64
#
# Top words for status 'schizophrenia':
# like             0.377679
# know             0.223216
# feel             0.219825
# people           0.176971
# get              0.171926
# would            0.168323
# walls            0.153064
# want             0.151495
# schizophrenia    0.144968
# really           0.144968
# Name: schizophrenia, dtype: float64

# %%
top_n = 10
for status in tfidf_df.index:
    print(f"\nTop words for status '{status}':")
    top_words = tfidf_df.loc[status].sort_values(ascending=True).head(top_n)
    print(top_words)
# Out:
# Top words for status 'Anxiety':
# stabilises          0.0
# laughters           0.0
# latudalurasidone    0.0
# latudathe           0.0
# latudazoloft        0.0
# latvia              0.0
# latyer              0.0
# laude               0.0
# laughable           0.0
# laughtermany        0.0
# Name: Anxiety, dtype: float64
#
# Top words for status 'BPD':
# migrainesheadaches    0.0
# tsi                   0.0
# tsinghua              0.0
# tske                  0.0
# tss                   0.0
# tstop                 0.0
# tsu                   0.0
# tsukuyomi             0.0
# tsunami               0.0
# migrainesfor          0.0
# Name: BPD, dtype: float64
#
# Top words for status 'Normal':
# partsome         0.0
# partyloving      0.0
# partyits         0.0
# partying         0.0
# partway          0.0
# partumn          0.0
# partum           0.0
# parttimetoday    0.0
# parttimei        0.0
# partthen         0.0
# Name: Normal, dtype: float64
#
# Top words for status 'Stress':
# paranoidmanipulating     0.0
# paraphernalia            0.0
# parapet                  0.0
# paranormalrelated        0.0
# paranormal               0.0
# paranoidtoo              0.0
# paranoidschizophrenia    0.0
# paranoidschiz            0.0
# paranoidpossessive       0.0
# paranoidpanicking        0.0
# Name: Stress, dtype: float64
#
# Top words for status 'Suicidal':
# livers                   0.0
# synergized               0.0
# synesthesia              0.0
# synethesia               0.0
# synonyms                 0.0
# synchronicity            0.0
# synchronicityexternal    0.0
# livepoker                0.0
# livereasons              0.0
# synergetic               0.0
# Name: Suicidal, dtype: float64
#
# Top words for status 'bipolar':
# myselfwell       0.0
# myselfthanks     0.0
# myselfthats      0.0
# myselfthe        0.0
# myselfthen       0.0
# myselfthere      0.0
# myselfthey       0.0
# myselfthis       0.0
# myselfthought    0.0
# myselftoday      0.0
# Name: bipolar, dtype: float64
#
# Top words for status 'depression':
# seananners               0.0
# sdx                      0.0
# sducidal                 0.0
# sdsma                    0.0
# sds                      0.0
# individuallyprivately    0.0
# individualizedcatered    0.0
# individualized           0.0
# individualize            0.0
# individualism            0.0
# Name: depression, dtype: float64
#
# Top words for status 'mentalillness':
# itriedcountlesstimestokillmyself    0.0
# iton                                0.0
# itold                               0.0
# singermusician                      0.0
# singeri                             0.0
# singerfriend                        0.0
# singerband                          0.0
# singel                              0.0
# itselfam                            0.0
# itseems                             0.0
# Name: mentalillness, dtype: float64
#
# Top words for status 'schizophrenia':
# onthen             0.0
# onwardspurely      0.0
# onused             0.0
# onus               0.0
# ontopoftheworld    0.0
# ontopic            0.0
# ontop              0.0
# ontook             0.0
# ontime             0.0
# onthis             0.0
# Name: schizophrenia, dtype: float64
