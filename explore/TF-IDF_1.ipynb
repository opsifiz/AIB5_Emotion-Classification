# %% [markdown]
# <a href="https://colab.research.google.com/github/opsifiz/AIB5_Mental-Health-Sentiment-Analysis/blob/main/explore/TF-IDF_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
# print(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
df = pd.read_csv('drive/MyDrive/cleaned_dataset.csv')
df
# Out:
#                                                       text         status from
# 0                                               oh my gosh        Anxiety  df1
# 1        trouble sleeping confused mind restless heart ...        Anxiety  df1
# 2        all wrong back off dear forward doubt stay in ...        Anxiety  df1
# 3        i have shifted my focus to something else but ...        Anxiety  df1
# 4        i am restless and restless it is been a month ...        Anxiety  df1
# ...                                                    ...            ...  ...
# 1093453  where can you go to get help for someone menta...  mentalillness  df3
# 1093454                          i am rooster illusion ama  mentalillness  df3
# 1093455  i look again to make sure so one is near me an...  mentalillness  df3
# 1093456  nami peertopeer is a unique experiential learn...  mentalillness  df3
# 1093457  crazy motherfucker so i have a lot of random i...  mentalillness  df3
#
# [1093458 rows x 3 columns]

# %%
df.describe()
# Out:
#                                                      text   status     from
# count                                             1093458  1093458  1093458
# unique                                            1093458       10        3
# top     crazy motherfucker so i have a lot of random i...      BPD      df3
# freq                                                    1   373788   594718

# %%
grouped = df.groupby('status')['text'].apply(lambda texts: ' '.join(texts))

# %%
grouped.head(10)
# Out:
# status
# Anxiety                 oh my gosh trouble sleeping confused mind rest...
# BPD                     my father all of my life has shifted between a...
# Normal                  gr gr dreaming of ex crush to be my game god w...
# Personality disorder    is there anyone interested in joining a group ...
# Stress                  he said he had not felt that way before sugget...
# Suicidal                i am so exhausted of this just when i think i ...
# bipolar                 what birth control are you on i tried an iud b...
# depression              i recently went through a breakup and she said...
# mentalillness           i feel the same towards a loved one and a comp...
# schizophrenia           does anyone else get frequent delusions that n...
# Name: text, dtype: object

# %%
stop_words = set(stopwords.words('english'))

# %%
def remove_stopwords(text):
    words = text.split()  # Tokenize and lowercase
    filtered_words = [word for word in words if word.isalpha() and word not in stop_words]
    return ' '.join(filtered_words)

# %%
all_status = grouped.index.to_list()
all_status
# Out:
# ['Anxiety',
#  'BPD',
#  'Normal',
#  'Personality disorder',
#  'Stress',
#  'Suicidal',
#  'bipolar',
#  'depression',
#  'mentalillness',
#  'schizophrenia']

# %%
for status in all_status:
  grouped[status] = remove_stopwords(grouped[status])

# %%
grouped.head(10)
# Out:
# status
# Anxiety                 oh gosh trouble sleeping confused mind restles...
# BPD                     father life shifted wonderful person monster b...
# Normal                  gr gr dreaming ex crush game god wkwkwk joke l...
# Personality disorder    anyone interested joining group avpd telegram ...
# Stress                  said felt way suggeted go rest trigger ahead y...
# Suicidal                exhausted think finally rest think maybe thing...
# bipolar                 birth control tried iud came traumatic assault...
# depression              recently went breakup said still wants friends...
# mentalillness           feel towards loved one complete stranger feel ...
# schizophrenia           anyone else get frequent delusions nobody like...
# Name: text, dtype: object

# %%
vectorizer = TfidfVectorizer()
tfidf_matrix = vectorizer.fit_transform(grouped)

# %%
tfidf_df = pd.DataFrame(tfidf_matrix.toarray(),
                        index=grouped.index,
                        columns=vectorizer.get_feature_names_out())

# %%
top_n = 10
for status in tfidf_df.index:
    print(f"\nTop words for status '{status}':")
    top_words = tfidf_df.loc[status].sort_values(ascending=False).head(top_n)
    print(top_words)
# Out:
# Top words for status 'Anxiety':
# anxiety    0.382289
# like       0.338196
# feel       0.262112
# get        0.200217
# know       0.194854
# really     0.153163
# time       0.145045
# would      0.137741
# cannot     0.136440
# even       0.132510
# Name: Anxiety, dtype: float64
#
# Top words for status 'BPD':
# like      0.367468
# feel      0.290249
# know      0.238659
# want      0.197751
# would     0.180873
# bpd       0.173052
# get       0.166811
# really    0.162859
# time      0.150471
# people    0.147739
# Name: BPD, dtype: float64
#
# Top words for status 'Normal':
# like      0.262041
# want      0.241569
# get       0.187911
# really    0.183601
# would     0.173688
# time      0.171102
# go        0.161620
# know      0.160327
# one       0.158819
# good      0.140718
# Name: Normal, dtype: float64
#
# Top words for status 'Personality disorder':
# like      0.395411
# people    0.290102
# feel      0.254521
# know      0.208896
# would     0.189958
# avpd      0.185757
# even      0.185080
# want      0.162124
# get       0.148925
# life      0.137160
# Name: Personality disorder, dtype: float64
#
# Top words for status 'Stress':
# like      0.314060
# feel      0.239789
# stress    0.229603
# get       0.219630
# know      0.202653
# time      0.181858
# cannot    0.160849
# would     0.158515
# even      0.150239
# really    0.142600
# Name: Stress, dtype: float64
#
# Top words for status 'Suicidal':
# want      0.319831
# like      0.272737
# cannot    0.237785
# life      0.228889
# feel      0.225252
# know      0.212329
# would     0.171877
# get       0.156700
# even      0.154776
# people    0.142454
# Name: Suicidal, dtype: float64
#
# Top words for status 'bipolar':
# like       0.348590
# feel       0.262299
# know       0.207000
# bipolar    0.204475
# get        0.177593
# time       0.154305
# really     0.152219
# want       0.147942
# would      0.146941
# cannot     0.124887
# Name: bipolar, dtype: float64
#
# Top words for status 'depression':
# like      0.338139
# feel      0.308893
# want      0.231010
# know      0.220668
# life      0.211287
# get       0.177799
# cannot    0.174249
# even      0.169974
# would     0.153637
# time      0.147409
# Name: depression, dtype: float64
#
# Top words for status 'mentalillness':
# like      0.373053
# feel      0.266705
# know      0.244113
# get       0.187773
# would     0.181834
# want      0.176077
# people    0.154503
# really    0.153064
# cannot    0.150000
# even      0.145811
# Name: mentalillness, dtype: float64
#
# Top words for status 'schizophrenia':
# like             0.375148
# feel             0.219009
# know             0.217789
# people           0.174746
# get              0.172616
# schizophrenia    0.171803
# would            0.167117
# want             0.148316
# really           0.142508
# time             0.142140
# Name: schizophrenia, dtype: float64

# %%
top_n = 10
for status in tfidf_df.index:
    print(f"\nTop words for status '{status}':")
    top_words = tfidf_df.loc[status].sort_values(ascending=True).head(top_n)
    print(top_words)
# Out:
# Top words for status 'Anxiety':
# talkedabout           0.0
# hypnosisrelaxation    0.0
# hypnoterapist         0.0
# hypnotherapyemdr      0.0
# talkcouple            0.0
# talkcry               0.0
# talkcuddle            0.0
# talkcw                0.0
# talkdate              0.0
# talkdid               0.0
# Name: Anxiety, dtype: float64
#
# Top words for status 'BPD':
# haupschulabschluss    0.0
# questiontell          0.0
# questionthanks        0.0
# questionwhich         0.0
# questionwhy           0.0
# questionworry         0.0
# questionxbi           0.0
# hauntings             0.0
# hauntingthanks        0.0
# hauntingthis          0.0
# Name: BPD, dtype: float64
#
# Top words for status 'Normal':
# petechaie           0.0
# peters              0.0
# peterparros         0.0
# peterpansyndrome    0.0
# petering            0.0
# petergwen           0.0
# petered             0.0
# petent              0.0
# petechiae           0.0
# petechia            0.0
# Name: Normal, dtype: float64
#
# Top words for status 'Personality disorder':
# pittblack       0.0
# pitting         0.0
# pittied         0.0
# pittie          0.0
# pitthis         0.0
# pitthere        0.0
# pitterpatter    0.0
# pittering       0.0
# pitter          0.0
# pitted          0.0
# Name: Personality disorder, dtype: float64
#
# Top words for status 'Stress':
# pierces             0.0
# pierdan             0.0
# piercingtattoo      0.0
# piercingstattoos    0.0
# piercings           0.0
# piercingly          0.0
# piercing            0.0
# piercieved          0.0
# piercetheveil       0.0
# piercescratch       0.0
# Name: Stress, dtype: float64
#
# Top words for status 'Suicidal':
# peoplephysically      0.0
# peoplepoststweets     0.0
# peopleposted          0.0
# peoplepolice          0.0
# peoplepleasing        0.0
# peoplepleased         0.0
# peopleplease          0.0
# peopleplacesthings    0.0
# peopleplaces          0.0
# peopleplaceor         0.0
# Name: Suicidal, dtype: float64
#
# Top words for status 'bipolar':
# moderatefunctioning    0.0
# modeller               0.0
# modelingrendering      0.0
# modelingl              0.0
# modelinganalysis       0.0
# modelingadult          0.0
# modelike               0.0
# modeli                 0.0
# modelguidance          0.0
# modeler                0.0
# Name: bipolar, dtype: float64
#
# Top words for status 'depression':
# informacin             0.0
# infocontext            0.0
# infodeceived           0.0
# infodense              0.0
# infodetails            0.0
# infodumping            0.0
# infodumpingrambling    0.0
# infodumps              0.0
# inforce                0.0
# inforced               0.0
# Name: depression, dtype: float64
#
# Top words for status 'mentalillness':
# outworst         0.0
# outya            0.0
# outy             0.0
# outxdxdanyone    0.0
# outxd            0.0
# outxbi           0.0
# outwright        0.0
# outwreaking      0.0
# outwould         0.0
# outyelled        0.0
# Name: mentalillness, dtype: float64
#
# Top words for status 'schizophrenia':
# othersones        0.0
# othersnever       0.0
# othersno          0.0
# othersnon         0.0
# othersnot         0.0
# othersnow         0.0
# othersomeone      0.0
# othersometimes    0.0
# otherson          0.0
# otherstake        0.0
# Name: schizophrenia, dtype: float64
