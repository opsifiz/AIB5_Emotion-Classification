# %% [markdown]
# <a href="https://colab.research.google.com/github/opsifiz/AIB5_Mental-Health-Sentiment-Analysis/blob/main/data/Explore_data_TF-IDF.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
# print(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
df = pd.read_csv('drive/MyDrive/train_dataset.csv')
df
# Out:
#                                                      text         status from  \
# 0                                              oh my gosh        Anxiety  df1
# 1       trouble sleeping confused mind restless heart ...        Anxiety  df1
# 2       all wrong back off dear forward doubt stay in ...        Anxiety  df1
# 3       i have shifted my focus to something else but ...        Anxiety  df1
# 4       i am restless and restless it is been a month ...        Anxiety  df1
# ...                                                   ...            ...  ...
# 104995  low testosterone after discontinuing rispredon...  schizophrenia  df3
# 104996  how did you finally accept your diagnosis i am...  schizophrenia  df3
# 104997  constantly feel like i am in a competition wit...  schizophrenia  df3
# 104998  has anyone switched over to an entirely differ...  schizophrenia  df3
# 104999  has anyone experienced anything like this psyc...  schizophrenia  df3
#
#                                                translated
# 0                                             โอ้พระเจ้า!
# 1       นอนไม่หลับ วุ่นวายใจ กระวนกระวายใจ ทุกอย่างดูผ...
# 2       ทุกอย่างไม่ถูกต้อง ถอยไปเถอะ อย่าก้าวไปข้างหน้...
# 3       ฉันพยายามเบนความสนใจไปเรื่องอื่นแล้ว แต่ก็ยังก...
# 4       ฉันกระวนกระวายใจมาก มันเป็นแบบนี้มาเป็นเดือนแล...
# ...                                                   ...
# 104995                                                  -
# 104996                                                  -
# 104997                                                  -
# 104998                                                  -
# 104999                                                  -
#
# [105000 rows x 4 columns]

# %%
df.describe()
# Out:
#                                                      text   status    from  \
# count                                              105000   105000  105000
# unique                                             105000        7       3
# top     has anyone experienced anything like this psyc...  Anxiety     df2
# freq                                                    1    15000   62893
#
#        translated
# count      105000
# unique       9948
# top             -
# freq        94927

# %%
grouped = df.groupby('status')['text'].apply(lambda texts: ' '.join(texts))

# %%
grouped.head(10)
# Out:
# status
# Anxiety          oh my gosh trouble sleeping confused mind rest...
# BPD              my father all of my life has shifted between a...
# Normal           gr gr dreaming of ex crush to be my game god w...
# bipolar          what birth control are you on i tried an iud b...
# depression       i recently went through a breakup and she said...
# mentalillness    i feel the same towards a loved one and a comp...
# schizophrenia    does anyone else get frequent delusions that n...
# Name: text, dtype: object

# %%
stop_words = set(stopwords.words('english'))

# %%
def remove_stopwords(text):
    words = text.split()  # Tokenize and lowercase
    filtered_words = [word for word in words if word.isalpha() and word not in stop_words]
    return ' '.join(filtered_words)

# %%
all_status = grouped.index.to_list()
all_status
# Out:
# ['Anxiety',
#  'BPD',
#  'Normal',
#  'bipolar',
#  'depression',
#  'mentalillness',
#  'schizophrenia']

# %%
for status in all_status:
  grouped[status] = remove_stopwords(grouped[status])

# %%
grouped.head(10)
# Out:
# status
# Anxiety          oh gosh trouble sleeping confused mind restles...
# BPD              father life shifted wonderful person monster b...
# Normal           gr gr dreaming ex crush game god wkwkwk joke l...
# bipolar          birth control tried iud came traumatic assault...
# depression       recently went breakup said still wants friends...
# mentalillness    feel towards loved one complete stranger feel ...
# schizophrenia    anyone else get frequent delusions nobody like...
# Name: text, dtype: object

# %%
vectorizer = TfidfVectorizer()
tfidf_matrix = vectorizer.fit_transform(grouped)

# %%
tfidf_df = pd.DataFrame(tfidf_matrix.toarray(),
                        index=grouped.index,
                        columns=vectorizer.get_feature_names_out())

# %%
top_n = 10
for status in tfidf_df.index:
    print(f"\nTop words for status '{status}':")
    top_words = tfidf_df.loc[status].sort_values(ascending=False).head(top_n)
    print(top_words)
# Out:
# Top words for status 'Anxiety':
# anxiety    0.346149
# like       0.335234
# feel       0.254662
# get        0.196528
# know       0.195920
# really     0.153958
# time       0.148825
# would      0.142478
# cannot     0.134245
# even       0.134035
# Name: Anxiety, dtype: float64
#
# Top words for status 'BPD':
# like      0.370442
# feel      0.292354
# know      0.237216
# want      0.193660
# would     0.182293
# really    0.166734
# get       0.165827
# bpd       0.157924
# time      0.150368
# people    0.143950
# Name: BPD, dtype: float64
#
# Top words for status 'Normal':
# like      0.265157
# want      0.244556
# get       0.188512
# really    0.183417
# would     0.176328
# time      0.170569
# know      0.161708
# go        0.160822
# one       0.158828
# good      0.141993
# Name: Normal, dtype: float64
#
# Top words for status 'bipolar':
# like       0.346944
# feel       0.260147
# know       0.210987
# bipolar    0.188308
# get        0.180951
# time       0.157832
# really     0.155007
# want       0.149988
# would      0.149525
# cannot     0.127162
# Name: bipolar, dtype: float64
#
# Top words for status 'depression':
# like      0.339134
# feel      0.306730
# want      0.227033
# know      0.219123
# life      0.205317
# get       0.185255
# even      0.169871
# time      0.153783
# cannot    0.152186
# people    0.146690
# Name: depression, dtype: float64
#
# Top words for status 'mentalillness':
# like      0.374817
# feel      0.266310
# know      0.239694
# get       0.188501
# would     0.184902
# want      0.177562
# really    0.154784
# people    0.153644
# cannot    0.149644
# even      0.148825
# Name: mentalillness, dtype: float64
#
# Top words for status 'schizophrenia':
# like             0.377297
# know             0.221303
# feel             0.220246
# people           0.176414
# get              0.171823
# would            0.167563
# schizophrenia    0.156598
# want             0.150586
# really           0.144938
# time             0.144847
# Name: schizophrenia, dtype: float64

# %%
top_n = 10
for status in tfidf_df.index:
    print(f"\nTop words for status '{status}':")
    top_words = tfidf_df.loc[status].sort_values(ascending=True).head(top_n)
    print(top_words)
# Out:
# Top words for status 'Anxiety':
# lowneedless     0.0
# lowself         0.0
# lowrider        0.0
# lowpost         0.0
# thanksxxxxxx    0.0
# thanksyall      0.0
# lowpaying       0.0
# lowpatch        0.0
# lowno           0.0
# lowness         0.0
# Name: Anxiety, dtype: float64
#
# Top words for status 'BPD':
# jin         0.0
# jinxcat     0.0
# jinjadev    0.0
# jinhwan     0.0
# jingle      0.0
# jingggg     0.0
# jing        0.0
# jincs       0.0
# jinbei      0.0
# jinxing     0.0
# Name: BPD, dtype: float64
#
# Top words for status 'Normal':
# minuteshoursor     0.0
# minuscule          0.0
# minut              0.0
# minutea            0.0
# minuteattention    0.0
# minutei            0.0
# minutesan          0.0
# minutesand         0.0
# minutesgoes        0.0
# minuteshe          0.0
# Name: Normal, dtype: float64
#
# Top words for status 'bipolar':
# lbswas            0.0
# leage             0.0
# ldrs              0.0
# ldw               0.0
# lea               0.0
# leaching          0.0
# leaded            0.0
# leaderboard       0.0
# leaderguide       0.0
# leadersliaison    0.0
# Name: bipolar, dtype: float64
#
# Top words for status 'depression':
# sellingbeliklaten    0.0
# indonesia            0.0
# indonesian           0.0
# indiscretions        0.0
# indiscriminate       0.0
# indiscriminately     0.0
# indispensable        0.0
# indisposed           0.0
# indistinct           0.0
# indomyyy             0.0
# Name: depression, dtype: float64
#
# Top words for status 'mentalillness':
# jour           0.0
# journeyeven    0.0
# journeyi       0.0
# journeying     0.0
# jotting        0.0
# jou            0.0
# jouer          0.0
# joueurs        0.0
# jouissances    0.0
# journeybut     0.0
# Name: mentalillness, dtype: float64
#
# Top words for status 'schizophrenia':
# lulus        0.0
# tacky        0.0
# tacoma       0.0
# tactful      0.0
# tactfully    0.0
# lunafiko     0.0
# lullaby      0.0
# lulled       0.0
# lulling      0.0
# lulu         0.0
# Name: schizophrenia, dtype: float64
